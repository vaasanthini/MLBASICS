# %% [markdown]
# <a href="https://colab.research.google.com/github/vaasanthini/MLBASICS/blob/main/ML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Create a Pandas DataFrame from the following dictionary:
# data = {
#  'Name': ['Alice', 'Bob', 'Carol'],
#  'Age': [24, 27, 22],
#  'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd

data = {
 'Name': ['Alice','Bob','Carol'],
 'Age': [24, 27, 22],
 'Salary': [50000, 55000, 48000]
}

df = pd.DataFrame(data)
df['Bonus'] = df['Salary'] * 0.1
print(df)
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# # 2.Given the DataFrame created in the above question:
# # • Display the first two rows.
# # • Compute the mean salary.

# %%
import pandas as pd
print(df.head(2))
mean_salary = df['Salary'].mean()
print(f"\nThe mean salary is: {mean_salary}")
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
#
# The mean salary is: 51000.0

# %% [markdown]
# # Using the same DataFrame:
# #• Extract all rows where the Age is greater than 25.
# # • Filter out rows where the Salary is less than 50000.

# %%
import pandas as pd
data = {
 'Name': ['Alice','Bob','Carol'],
 'Age': [24, 27, 22],
 'Salary': [50000, 55000, 48000]
}
df = pd.DataFrame(data)
age_filter = df['Age'] > 25
df_age = df[age_filter]
print("Rows where Age > 25:\n", df_age)
salary_filter = df['Salary'] >= 50000
df_salary = df[salary_filter]
print("\nRows where Salary >= 50000:\n", df_salary)
# Out:
# Rows where Age > 25:
#    Name  Age  Salary
# 1  Bob   27   55000
#
# Rows where Salary >= 50000:
#      Name  Age  Salary
# 0  Alice   24   50000
# 1    Bob   27   55000

# %% [markdown]
# # Create the following DataFrame:
# # data = {
# # 'A': [1, 2, None, 4],
# # 'B': [None, 2, 3, None],
# # 'C': [1, 2, 3, 4]
# # }
# # df = pd.DataFrame(data)
# # • Fill missing values in column A with the mean of the column.
# # • Drop rows where all values are None.

# %%
import pandas as pd

# Create the DataFrame
data = {
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, None],
    'C': [1, 2, 3, 4]
}
df = pd.DataFrame(data)

# Fill missing values in column A with the mean of the column
mean_A = df['A'].mean()
df['A'].fillna(mean_A, inplace=True)

# Drop rows where all values are None
df.dropna(how='all', inplace=True)

# Display the resulting DataFrame
print(df)

# %% [markdown]
# # 5. Create a DataFrame for employees:
# ## data = {
# ## 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
# ## 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
# ## 'Salary': [50000, 45000, 60000, 65000, 70000]
# # }
# ## • Group the data by Department and compute the total and mean salary for each
# ## department.

# %%
import pandas as pd

data = {
    'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
    'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Salary': [50000, 45000, 60000, 65000, 70000]
}

df = pd.DataFrame(data)

department_stats = df.groupby('Department')['Salary'].agg(['sum', 'mean'])
department_stats
# Out:
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# ## 6. Given two DataFrames:
# ### df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# ### df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# ### • Perform an inner join on the ID column.

# %%
import pandas as pd
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
merged_df = pd.merge(df1, df2, on='ID', how='inner')
merged_df
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# #7. Given a small dataset, clean and display basic statistics using Pandas

# %%
import pandas as pd
data = {'A': [1, 2, None, 4, 5],
        'B': [6, 7, 8, None, 10],
        'C': [2, 7, 7,7, 1]}
df = pd.DataFrame(data)
print(df.describe())
df.fillna(df.mean(), inplace=True)
print(df.describe())
# Out:
#               A          B        C
# count  4.000000   4.000000  5.00000
# mean   3.000000   7.750000  4.80000
# std    1.825742   1.707825  3.03315
# min    1.000000   6.000000  1.00000
# 25%    1.750000   6.750000  2.00000
# 50%    3.000000   7.500000  7.00000
# 75%    4.250000   8.500000  7.00000
# max    5.000000  10.000000  7.00000
#               A         B        C
# count  5.000000   5.00000  5.00000
# mean   3.000000   7.75000  4.80000
# std    1.581139   1.47902  3.03315
# min    1.000000   6.00000  1.00000
# 25%    2.000000   7.00000  2.00000
# 50%    3.000000   7.75000  7.00000
# 75%    4.000000   8.00000  7.00000
# max    5.000000  10.00000  7.00000

# %% [markdown]
# #8. Small EDA task
# # • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# # • Perform the following tasks:
# # o Display the number of missing values in each column.
# # o Find the average age of passengers.
# # o Create a bar plot to show the survival rate based on gender.

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic_df = pd.read_csv('/content/Titanic-Dataset.csv')
print("Missing Values per Column:\n", titanic_df.isnull().sum())

average_age = titanic_df['Age'].mean()
print(f"\nAverage age of passengers: {average_age}\n")

survival_by_gender = titanic_df.groupby('Sex')['Survived'].mean()
survival_by_gender.plot(kind='bar')
plt.title('--Survival Rate by Gender--')
plt.xlabel('Gender----->')
plt.ylabel('Survival Rate----->')
plt.xticks(rotation=0)
plt.show()
# Out:
# Missing Values per Column:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Average age of passengers: 29.69911764705882

# %% [markdown]
# #9. Data Transformation
# # • Load a dataset containing daily temperatures and dates. Perform the following:
# # o Convert the date column into a DateTime object.
# # o Create a new column that categorizes temperatures into High, Medium, or
# # Low

# %%
import pandas as pd
temp_df = pd.read_csv('/content/daily-min-temperatures.csv')
df = pd.DataFrame(temp_df)
df['Date'] = pd.to_datetime(df['Date'])
def categorize_temperature(temp):
    if temp > 25:
        return 'High'
    elif temp >= 15:
        return 'Medium'
    else:
        return 'Low'
df['TemperatureCategory'] = df['Temp'].apply(categorize_temperature)
print(df)
# Out:
#            Date  Temp TemperatureCategory
# 0    1981-01-01  20.7              Medium
# 1    1981-01-02  17.9              Medium
# 2    1981-01-03  18.8              Medium
# 3    1981-01-04  14.6                 Low
# 4    1981-01-05  15.8              Medium
# ...         ...   ...                 ...
# 3645 1990-12-27  14.0                 Low
# 3646 1990-12-28  13.6                 Low
# 3647 1990-12-29  13.5                 Low
# 3648 1990-12-30  15.7              Medium
# 3649 1990-12-31  13.0                 Low
#
# [3650 rows x 3 columns]
